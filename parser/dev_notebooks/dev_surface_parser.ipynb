# %%
import os
import ray
import time
import numpy as np
import pandas as pd
from typing import List
from utils.data import load_yaml
from imaris.imaris import ImarisDataObject
#from parsers.surface_parser import SurfaceParserDistributed
from parsers_v2.surface_parser import (
    SurfaceParserDistributed as SurfaceParserDistributed_v2,
)

# %%
# ims_file = "/home/shehan/Documents/projects/nih/nih_parsers/data/surface/P2 rectum merged restained_1_[ims1_2025-08-18T14-27-29.640].ims"
ims_file = "/home/shehan/Documents/projects/nih/nih_parsers/data/tracks/GFP #1 Sec2 Roi1 2x2 1h30min.ims"
#parser = SurfaceParserDistributed(ims_file_path=ims_file)
parser_v2 = SurfaceParserDistributed_v2(ims_file_path=ims_file)
ims = ImarisDataObject(ims_file)
data = ims.data

# %%
start = time.perf_counter()
out = parser_v2.inspect(0)
stop = time.perf_counter()
print(f"run time: {stop - start}")
# Out:
# run time: 9.4131262130104

# %%
parser_v2.factors
# Out:
# {0:     ID_List        Name                        Level
#  0         1  Collection          Acceleration Vector
#  1         2  Collection         BoundingBoxAA Length
#  2         3  Collection         BoundingBoxOO Length
#  3         4  Collection   Center of Homogeneous Mass
#  4         5     Channel                            1
#  ..      ...         ...                          ...
#  64       40  Collection  Track Ellipsoid Axis C Mean
#  65       41  Collection               Track Position
#  66       42  Collection         Track Position Start
#  67       43  Collection               Velocity Angle
#  68       44  Collection                     Velocity
#
#  [69 rows x 3 columns],
#  1:     ID_List        Name                        Level
#  0         1  Collection          Acceleration Vector
#  1         2  Collection         BoundingBoxAA Length
#  2         3  Collection         BoundingBoxOO Length
#  3         4  Collection   Center of Homogeneous Mass
# ...

# %%
ims.get_object_names("Surface")
# Out:
# ['MegaSurfaces0',
#  'MegaSurfaces1',
#  'MegaSurfaces2',
#  'MegaSurfaces3',
#  'MegaSurfaces4',
#  'MegaSurfaces5',
#  'MegaSurfaces6',
#  'MegaSurfaces7']

# %%
factor = ims.get_object_factor("MegaSurfaces0")
factor
# Out:
#     ID_List        Name                        Level
# 0         1  Collection          Acceleration Vector
# 1         2  Collection         BoundingBoxAA Length
# 2         3  Collection         BoundingBoxOO Length
# 3         4  Collection   Center of Homogeneous Mass
# 4         5     Channel                            1
# ..      ...         ...                          ...
# 64       40  Collection  Track Ellipsoid Axis C Mean
# 65       41  Collection               Track Position
# 66       42  Collection         Track Position Start
# 67       43  Collection               Velocity Angle
# 68       44  Collection                     Velocity
#
# [69 rows x 3 columns]

# %%
current = list(factor[factor["Name"] == "Surfaces"]["Level"])
full_set = []
for k, v in parser_v2.factors.items():
    if k != 0:
        full_set.extend(v[v["Name"] == "Surfaces"]["Level"])
        
full_set = set(full_set)
missing = list(set(full_set) - set(current))

# %%
missing
# Out:
# ['Surfaces Unnamed 1 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]']

# %%
def _get_name(idx):
    current = list(factor[factor["Name"] == "Surfaces"]["Level"])
    full_set = []
    for k, v in parser_v2.factors.items():
        if k != 0:
            full_set.extend(v[v["Name"] == "Surfaces"]["Level"])
            
    full_set = set(full_set)
    missing = list(set(full_set) - set(current))
# Out:
# {'Surfaces Unnamed 1 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]',
#  'Surfaces Unnamed 1 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]',
#  'Surfaces Unnamed 2 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]',
#  'Surfaces Unnamed 2 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]',
#  'Surfaces Unnamed 3 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]',
#  'Surfaces Unnamed 3 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]',
#  'Surfaces Unnamed 4 BCGmR.icsx_[ibrx_2023-06-26T09-47-24.240]',
#  'Surfaces Unnamed 4 CG.GC.C-.G-.icsx_[ibrx_2023-09-27T11-04-45.364]'}

# %%
start = time.perf_counter()
out_v2 = parser_v2.inspect(0)
stop = time.perf_counter()
print(f"run time: {stop - start}")

# %%
final = out["final_df"]
final_v2 = out_v2["final_df"]
print(final.equals(final_v2))
print(final_v2.equals(final))

# %%
ims.contains_tracks("MegaSurfaces0")

# %%
for i in list(final.columns):
    if i not in list(final_v2.columns):
        print(i)

# %%
for i in list(final_v2.columns):
    if i not in list(final.columns):
        print(i)
