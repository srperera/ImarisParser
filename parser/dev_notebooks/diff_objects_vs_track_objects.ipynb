# %% [markdown]
# * looking at the difference between objects and track objects in a ims file.
# * what kind of different stats are available between these two objects

# %%
import sys

sys.path.append("..")
import os
import ray
import time
import numpy as np
import pandas as pd
from typing import List
from utils.data import load_yaml
from imaris.imaris import ImarisDataObject
from parsers_v2.spot_track_object_parser import SpotTrackObjectParserDistributed

# %%
ims_file = "/home/shehan/Documents/projects/nih/nih_parsers/data/spots/Day2 RFL Gran2 3x3 2h_[ii9_TileScan_003_Merging001_Image_10].ims"
parser = SpotTrackObjectParserDistributed(ims_file_path=ims_file)
ims = ImarisDataObject(ims_file)
data = ims.data

# %%
with_tracks = parser.inspect(0)
no_tracks = parser.inspect(2)
# Out:
# (5096, 5) (263233,)
# time: 0.06759134074673057
# time organize stats: 12.726062496192753
# time update track info: 1.818714669905603
# (3590, 5) (3766,)
# time: 0.01912289997562766
# time organize stats: 0.15523381810635328
# Spot ID: 2 -- Spot Name: Points2 -- Contains No Tracks, Track ID Unavilable.

# %%
final_df_tracks = with_tracks["final_df"]
final_df_no_tracks = no_tracks["stats_df"]

print(
    f"tracks num stats: {final_df_tracks.shape[1]} -- num unique: {len(set(final_df_tracks.columns))}"
)
print(
    f"no_tracks num stats: {final_df_no_tracks.shape[1]} -- num unique: {len(set(final_df_no_tracks.columns))}"
)
# Out:
# tracks num stats: 74 -- num unique: 74
# no_tracks num stats: 52 -- num unique: 52

# %%
# what stats are missing in no tracks
for stat in list(final_df_tracks.columns):
    if stat not in list(final_df_no_tracks.columns):
        print(stat)
# Out:
# Acceleration
# Acceleration X
# Acceleration Y
# Acceleration Z
# Displacement Delta Length
# Displacement Delta X
# Displacement Delta Y
# Displacement Delta Z
# Displacement Length
# Displacement X
# Displacement Y
# Displacement Z
# Displacement^2
# Speed
# Time Since Track Start
# Velocity Angle X
# Velocity Angle Y
# Velocity Angle Z
# Velocity X
# Velocity Y
# Velocity Z
# Track_ID
